# %% [markdown]
# # Fundamentals of Computer Algorithms - Ellis Horowitz
#
# This notebook is a structured study guide inspired by the classic text *Fundamentals of Computer Algorithms* by Ellis Horowitz. It covers the essential ideas behind algorithm design, analysis, and problem solving.

# %% [markdown]
# ## 1. What is an Algorithm?
#
# An algorithm is a precise sequence of steps that solves a problem. Good algorithms are:
# - correct
# - efficient
# - easy to understand and implement

# %%
# A simple algorithm: find the maximum in a list
def find_max(values):
    current_max = values[0]
    for value in values[1:]:
        if value > current_max:
            current_max = value
    return current_max

print(find_max([4, 9, 1, 7, 3]))

# %% [markdown]
# ## 2. Algorithm Analysis
#
# We analyze algorithms by measuring how their running time and memory grow as the size of the input increases.

# %%
import time

def linear_search(values, target):
    for i, v in enumerate(values):
        if v == target:
            return i
    return -1

large_list = list(range(100000))
start = time.time()
linear_search(large_list, 99999)
print(f"Elapsed seconds: {time.time() - start:.6f}")

# %% [markdown]
# ## 3. Asymptotic Notation
#
# Common notations used in algorithm analysis:
# - $O(1)$: constant time
# - $O(log n)$: logarithmic time
# - $O(n)$: linear time
# - $O(n log n)$: linearithmic time
# - $O(n^2)$: quadratic time

# %%
import math

def compare_growth(n):
    return {
        "O(1)": 1,
        "O(log n)": math.log2(n),
        "O(n)": n,
        "O(n log n)": n * math.log2(n),
        "O(n^2)": n * n,
    }

n = 16
for name, value in compare_growth(n).items():
    print(name, value)

# %% [markdown]
# ## 4. Recurrence Relations
#
# Many divide-and-conquer algorithms lead to recurrences such as:
# $T(n) = 2T(n/2) + O(n)$
# which describes merge sort.

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

print(merge_sort([5, 2, 9, 1, 7, 3]))

# %% [markdown]
# ## 5. Brute Force and Exhaustive Search
#
# Brute force checks all possible solutions. It is simple but often expensive.

# %%
from itertools import combinations

def brute_force_sum(values, target):
    for r in range(1, len(values) + 1):
        for combo in combinations(values, r):
            if sum(combo) == target:
                return combo
    return None

print(brute_force_sum([2, 4, 6, 8], 10))

# %% [markdown]
# ## 6. Divide and Conquer
#
# This technique breaks a problem into smaller independent subproblems, solves them recursively, and combines the answers.

# %%
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        if arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

arr = [1, 3, 5, 7, 9, 11]
print(binary_search(arr, 7))

# %% [markdown]
# ## 7. Greedy Algorithms
#
# Greedy methods make locally optimal choices to reach a global solution. They are fast, but not always correct for every problem.

# %%
def activity_selection(start, finish):
    activities = sorted(zip(start, finish), key=lambda x: x[1])
    selected = []
    last_finish = -1
    for s, f in activities:
        if s >= last_finish:
            selected.append((s, f))
            last_finish = f
    return selected

print(activity_selection([1, 3, 0, 5, 8, 5], [2, 4, 6, 7, 9, 9]))

# %% [markdown]
# ## 8. Dynamic Programming
#
# Dynamic programming avoids recomputing subproblems by storing their results. It is useful for optimization problems.

# %%
def fibonacci(n):
    dp = [0, 1]
    for _ in range(2, n + 1):
        dp.append(dp[-1] + dp[-2])
    return dp[n]

print(fibonacci(10))

# %% [markdown]
# ## 9. Backtracking
#
# Backtracking builds partial solutions and abandons branches that cannot lead to a valid answer.

# %%
def n_queens(n):
    solutions = []

    def backtrack(row, cols, diag1, diag2):
        if row == n:
            solutions.append(cols.copy())
            return
        for col in range(n):
            if col in cols or (row - col) in diag1 or (row + col) in diag2:
                continue
            cols.append(col)
            diag1.append(row - col)
            diag2.append(row + col)
            backtrack(row + 1, cols, diag1, diag2)
            cols.pop()
            diag1.pop()
            diag2.pop()

    backtrack(0, [], [], [])
    return solutions

print(n_queens(4))

# %% [markdown]
# ## 10. Graph Algorithms
#
# Graphs model relationships between objects. Important techniques include BFS, DFS, shortest paths, and minimum spanning trees.

# %%
from collections import deque

def bfs(graph, start):
    visited = set([start])
    queue = deque([start])
    while queue:
        node = queue.popleft()
        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)
    return visited

graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': [],
    'F': []
}
print(bfs(graph, 'A'))

# %% [markdown]
# ## 11. Lower Bounds and Complexity Classes
#
# Some problems are inherently hard, meaning that no efficient algorithm is known for them. This motivates the study of NP-complete problems.

# %% [markdown]
# ## 12. Summary and Study Advice
#
# A strong understanding of algorithms comes from practicing three things:
# 1. Learn the idea behind each technique.
# 2. Compare time and space complexity.
# 3. Implement and test the algorithm on examples.
